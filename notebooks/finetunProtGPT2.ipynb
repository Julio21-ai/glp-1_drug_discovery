# %% [markdown]
#  # Workflow: Fine-Tuning de ProtGPT2 y Generación
#
#  Este notebook cubre el proceso completo:
#  1.  Instalar dependencias.
#  2.  Descargar el script de entrenamiento de Hugging Face.
#  3.  Cargar datos desde un CSV (usando pandas).
#  4.  Formatear y guardar los datos en `training.txt` y `validation.txt`.
#  5.  Ejecutar el fine-tuning (re-entrenamiento).
#  6.  Cargar el nuevo modelo "tuneado".
#  7.  Generar secuencias con el nuevo modelo.
#  8.  Calcular la Perplejidad (PPL) de las secuencias generadas.

# %%
# !pip install transformers torch accelerate datasets pandas scikit-learn biopython
# !pip install transformers torch accelerate datasets pandas scikit-learn biopython evaluate
# Out:
# Requirement already satisfied: transformers in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (5.0.0.dev0)
# Requirement already satisfied: torch in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (2.9.0+cu128)
# Requirement already satisfied: accelerate in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (1.10.1)
# Requirement already satisfied: datasets in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (4.2.0)
# Requirement already satisfied: pandas in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (2.1.4)
# Requirement already satisfied: scikit-learn in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (1.4.2)
# Requirement already satisfied: biopython in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (1.85)
# Requirement already satisfied: filelock in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub==1.0.0.rc6 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (1.0.0rc6)
# Requirement already satisfied: numpy>=1.17 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: typer-slim in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (0.19.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from huggingface-hub==1.0.0.rc6->transformers) (2025.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from huggingface-hub==1.0.0.rc6->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from huggingface-hub==1.0.0.rc6->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (4.11.0)
# Requirement already satisfied: certifi in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: psutil in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: xxhash in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from typer-slim->transformers) (8.2.1)
# Requirement already satisfied: transformers in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (5.0.0.dev0)
# Requirement already satisfied: torch in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (2.9.0+cu128)
# Requirement already satisfied: accelerate in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (1.10.1)
# Requirement already satisfied: datasets in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (4.2.0)
# Requirement already satisfied: pandas in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (2.1.4)
# Requirement already satisfied: scikit-learn in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (1.4.2)
# Requirement already satisfied: biopython in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (1.85)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: filelock in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub==1.0.0.rc6 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (1.0.0rc6)
# Requirement already satisfied: numpy>=1.17 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: typer-slim in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (0.19.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from huggingface-hub==1.0.0.rc6->transformers) (2025.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from huggingface-hub==1.0.0.rc6->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from huggingface-hub==1.0.0.rc6->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (4.11.0)
# Requirement already satisfied: certifi in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: psutil in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: xxhash in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\dev\.conda\envs\glp1-predict\lib\site-packages (from typer-slim->transformers) (8.2.1)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6

# %%
import requests

url = "https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/language-modeling/run_clm.py"
r = requests.get(url)
with open("run_clm.py", "wb") as f:
    f.write(r.content)

# Verificar
import os
print(os.listdir("."))
# Out:
# ['appx', 'bin', 'chrome_100_percent.pak', 'chrome_200_percent.pak', 'Code.exe', 'Code.VisualElementsManifest.xml', 'd3dcompiler_47.dll', 'ffmpeg.dll', 'icudtl.dat', 'libEGL.dll', 'libGLESv2.dll', 'LICENSES.chromium.html', 'locales', 'policies', 'resources', 'resources.pak', 'run_clm.py', 'snapshot_blob.bin', 'tools', 'unins000.dat', 'unins000.exe', 'unins000.msg', 'v8_context_snapshot.bin', 'vk_swiftshader.dll', 'vk_swiftshader_icd.json', 'vulkan-1.dll']

# %%
# %%python
# --- 3. Cargar y Preparar los Datos ---
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from Bio import SeqIO # Usaremos esto solo para el formato, pero adaptado

# --- Configuración de Archivos ---
CSV_INPUT_FILE = "D:/source/Proyecto Integrador/glp-1_drug_discovery/data/processed/descriptores_cdhit.csv"  # <--- ¡CAMBIA ESTO A TU ARCHIVO!
SEQUENCE_COLUMN = "sequence"     # <--- ¡CAMBIA ESTO AL NOMBRE DE TU COLUMNA!

TRAIN_FILE_TXT = "training.txt"
VAL_FILE_TXT = "validation.txt"
SPECIAL_TOKEN = "<|endoftext|>"
TEST_SPLIT_SIZE = 0.10  # 10% para validación
RANDOM_SEED = 42

# Expresión regular para aminoácidos canónicos
valid_aa_regex = re.compile(r"^[ACDEFGHIKLMNPQRSTVWY]+$")

# --- 3.1. Cargar Datos del CSV ---
try:
    df = pd.read_csv(CSV_INPUT_FILE)
    print(f"DataFrame cargado. Columnas: {df.columns.tolist()}")
    
    if SEQUENCE_COLUMN not in df.columns:
        print(f"¡ERROR! No se encontró la columna '{SEQUENCE_COLUMN}' en el CSV.")
        # Detener la ejecución si la columna no existe
        raise KeyError(f"Columna '{SEQUENCE_COLUMN}' no encontrada.")
        
    sequences = df[SEQUENCE_COLUMN].dropna().astype(str).tolist()
    print(f"Se extrajeron {len(sequences)} secuencias de la columna '{SEQUENCE_COLUMN}'.")

except FileNotFoundError:
    print(f"¡ERROR! No se encontró el archivo {CSV_INPUT_FILE}.")
    sequences = [] # Dejar la lista vacía para que el resto del script no falle

# --- 3.2. Validar y Limpiar Secuencias ---
valid_sequences = []
for seq_str in sequences:
    seq_str = seq_str.strip().upper().replace("\n", "").replace(" ", "")
    if seq_str and valid_aa_regex.match(seq_str):
        valid_sequences.append(seq_str)
    else:
        print(f"  > Omitiendo secuencia (vacía o con caracteres inválidos): {seq_str[:30]}...")

print(f"Se procesaron {len(valid_sequences)} secuencias válidas.")

# --- 3.3. División de Datos (Train/Validation) ---
if valid_sequences:
    train_seqs, val_seqs = train_test_split(
        valid_sequences, 
        test_size=TEST_SPLIT_SIZE, 
        random_state=RANDOM_SEED
    )
    print(f"División: {len(train_seqs)} para entrenamiento, {len(val_seqs)} para validación.")

    # --- 3.4. Función para Escribir Archivos ---
    def write_to_file(filename, seq_list):
        with open(filename, 'w', encoding='utf-8') as f:
            for seq in seq_list:
                f.write(f"{SPECIAL_TOKEN}\n")
                f.write(f"{seq}\n")
        print(f"Archivo guardado: {filename}")

    # --- 3.5. Escribir Archivos ---
    write_to_file(TRAIN_FILE_TXT, train_seqs)
    write_to_file(VAL_FILE_TXT, val_seqs)
else:
    print("No se encontraron secuencias válidas para procesar. No se crearán archivos de entrenamiento.")

print("¡Proceso de preparación de datos completado!")
# Out:
# DataFrame cargado. Columnas: ['ID', 'AAC_A', 'AAC_C', 'AAC_D', 'AAC_E', 'AAC_F', 'AAC_G', 'AAC_H', 'AAC_I', 'AAC_K', 'AAC_L', 'AAC_M', 'AAC_N', 'AAC_P', 'AAC_Q', 'AAC_R', 'AAC_S', 'AAC_T', 'AAC_V', 'AAC_W', 'AAC_Y', 'CKSAAGP_alphaticr.alphaticr.gap0', 'CKSAAGP_alphaticr.aromatic.gap0', 'CKSAAGP_alphaticr.postivecharger.gap0', 'CKSAAGP_alphaticr.negativecharger.gap0', 'CKSAAGP_alphaticr.uncharger.gap0', 'CKSAAGP_aromatic.alphaticr.gap0', 'CKSAAGP_aromatic.aromatic.gap0', 'CKSAAGP_aromatic.postivecharger.gap0', 'CKSAAGP_aromatic.negativecharger.gap0', 'CKSAAGP_aromatic.uncharger.gap0', 'CKSAAGP_postivecharger.alphaticr.gap0', 'CKSAAGP_postivecharger.aromatic.gap0', 'CKSAAGP_postivecharger.postivecharger.gap0', 'CKSAAGP_postivecharger.negativecharger.gap0', 'CKSAAGP_postivecharger.uncharger.gap0', 'CKSAAGP_negativecharger.alphaticr.gap0', 'CKSAAGP_negativecharger.aromatic.gap0', 'CKSAAGP_negativecharger.postivecharger.gap0', 'CKSAAGP_negativecharger.negativecharger.gap0', 'CKSAAGP_negativecharger.uncharger.gap0', 'CKSAAGP_uncharger.alphaticr.gap0', 'CKSAAGP_uncharger.aromatic.gap0', 'CKSAAGP_uncharger.postivecharger.gap0', 'CKSAAGP_uncharger.negativecharger.gap0', 'CKSAAGP_uncharger.uncharger.gap0', 'CKSAAGP_alphaticr.alphaticr.gap1', 'CKSAAGP_alphaticr.aromatic.gap1', 'CKSAAGP_alphaticr.postivecharger.gap1', 'CKSAAGP_alphaticr.negativecharger.gap1', 'CKSAAGP_alphaticr.uncharger.gap1', 'CKSAAGP_aromatic.alphaticr.gap1', 'CKSAAGP_aromatic.aromatic.gap1', 'CKSAAGP_aromatic.postivecharger.gap1', 'CKSAAGP_aromatic.negativecharger.gap1', 'CKSAAGP_aromatic.uncharger.gap1', 'CKSAAGP_postivecharger.alphaticr.gap1', 'CKSAAGP_postivecharger.aromatic.gap1', 'CKSAAGP_postivecharger.postivecharger.gap1', 'CKSAAGP_postivecharger.negativecharger.gap1', 'CKSAAGP_postivecharger.uncharger.gap1', 'CKSAAGP_negativecharger.alphaticr.gap1', 'CKSAAGP_negativecharger.aromatic.gap1', 'CKSAAGP_negativecharger.postivecharger.gap1', 'CKSAAGP_negativecharger.negativecharger.gap1', 'CKSAAGP_negativecharger.uncharger.gap1', 'CKSAAGP_uncharger.alphaticr.gap1', 'CKSAAGP_uncharger.aromatic.gap1', 'CKSAAGP_uncharger.postivecharger.gap1', 'CKSAAGP_uncharger.negativecharger.gap1', 'CKSAAGP_uncharger.uncharger.gap1', 'CKSAAGP_alphaticr.alphaticr.gap2', 'CKSAAGP_alphaticr.aromatic.gap2', 'CKSAAGP_alphaticr.postivecharger.gap2', 'CKSAAGP_alphaticr.negativecharger.gap2', 'CKSAAGP_alphaticr.uncharger.gap2', 'CKSAAGP_aromatic.alphaticr.gap2', 'CKSAAGP_aromatic.aromatic.gap2', 'CKSAAGP_aromatic.postivecharger.gap2', 'CKSAAGP_aromatic.negativecharger.gap2', 'CKSAAGP_aromatic.uncharger.gap2', 'CKSAAGP_postivecharger.alphaticr.gap2', 'CKSAAGP_postivecharger.aromatic.gap2', 'CKSAAGP_postivecharger.postivecharger.gap2', 'CKSAAGP_postivecharger.negativecharger.gap2', 'CKSAAGP_postivecharger.uncharger.gap2', 'CKSAAGP_negativecharger.alphaticr.gap2', 'CKSAAGP_negativecharger.aromatic.gap2', 'CKSAAGP_negativecharger.postivecharger.gap2', 'CKSAAGP_negativecharger.negativecharger.gap2', 'CKSAAGP_negativecharger.uncharger.gap2', 'CKSAAGP_uncharger.alphaticr.gap2', 'CKSAAGP_uncharger.aromatic.gap2', 'CKSAAGP_uncharger.postivecharger.gap2', 'CKSAAGP_uncharger.negativecharger.gap2', 'CKSAAGP_uncharger.uncharger.gap2', 'CKSAAGP_alphaticr.alphaticr.gap3', 'CKSAAGP_alphaticr.aromatic.gap3', 'CKSAAGP_alphaticr.postivecharger.gap3', 'CKSAAGP_alphaticr.negativecharger.gap3', 'CKSAAGP_alphaticr.uncharger.gap3', 'CKSAAGP_aromatic.alphaticr.gap3', 'CKSAAGP_aromatic.aromatic.gap3', 'CKSAAGP_aromatic.postivecharger.gap3', 'CKSAAGP_aromatic.negativecharger.gap3', 'CKSAAGP_aromatic.uncharger.gap3', 'CKSAAGP_postivecharger.alphaticr.gap3', 'CKSAAGP_postivecharger.aromatic.gap3', 'CKSAAGP_postivecharger.postivecharger.gap3', 'CKSAAGP_postivecharger.negativecharger.gap3', 'CKSAAGP_postivecharger.uncharger.gap3', 'CKSAAGP_negativecharger.alphaticr.gap3', 'CKSAAGP_negativecharger.aromatic.gap3', 'CKSAAGP_negativecharger.postivecharger.gap3', 'CKSAAGP_negativecharger.negativecharger.gap3', 'CKSAAGP_negativ ...
# Se extrajeron 225 secuencias de la columna 'sequence'.
# Se procesaron 225 secuencias válidas.
# División: 202 para entrenamiento, 23 para validación.
# Archivo guardado: training.txt
# Archivo guardado: validation.txt
# ¡Proceso de preparación de datos completado!

# %%
# Ajusta los parámetros según tu GPU y necesidades.

# Directorio donde se guardará el modelo
OUTPUT_MODEL_DIR = "C:/temp/protgpt2_finetuned"

# ¡Asegúrate de tener GPU disponible!
# !python run_clm.py \
    --model_name_or_path nferruz/ProtGPT2 \
    --tokenizer_name nferruz/ProtGPT2 \
    --train_file {TRAIN_FILE_TXT} \
    --validation_file {VAL_FILE_TXT} \
    --output_dir {OUTPUT_MODEL_DIR} \
    --do_train \
    --do_eval \
    --learning_rate 1e-6 \
    --num_train_epochs 3 \
    --per_device_train_batch_size 2 \
    --per_device_eval_batch_size 2 \
    --gradient_accumulation_steps 4 \
    --save_strategy "epoch" \
    --eval_strategy "epoch" \
    --fp16=True \
    --logging_steps 100

print(f"¡Entrenamiento completado! Modelo guardado en {OUTPUT_MODEL_DIR}")
# Out:
# 10/27/2025 15:45:13 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: True
# 10/27/2025 15:45:13 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# average_tokens_across_devices=True,
# batch_eval_metrics=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_on_start=False,
# eval_steps=None,
# eval_strategy=IntervalStrategy.EPOCH,
# eval_use_gather_object=False,
# fp16=True,
# fp16_full_eval=False,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# full_determinism=False,
# gradient_accumulation_steps=4,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=None,
# hub_revision=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_for_metrics=[],
# include_num_input_tokens_seen=no,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=1e-06,
# length_column_name=length,
# liger_kernel_config=None,
# load_best_model_at_end=False,
# local_rank=-1,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=100,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs=None,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# neftune_noise_alpha=None,
# num_train_epochs=3.0,
# optim=OptimizerNames.ADAMW_TORCH_FUSED,
# optim_args=None,
# optim_target_modules=None,
# output_dir=C:/temp/protgpt2_finetuned,
# parallelism_config=None,
# per_device_eval_batch_size=2,
# per_device_train_batch_size=2,
# prediction_loss_only=False,
# project=huggingface,
# push_to_hub=False,
# remove_unused_columns=True,
# report_to=[],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=None,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=SaveStrategy.EPOCH,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_empty_cache_steps=None,
# trackio_space_id=trackio,
# use_cache=False,
# use_cpu=False,
# use_liger_kernel=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# 10/27/2025 15:45:14 - INFO - datasets.builder - Using custom data configuration default-5d3022183dd3c5bc
# 10/27/2025 15:45:14 - INFO - datasets.builder - Generating dataset text (C:/Users/Dev/.cache/huggingface/datasets/text/default-5d3022183dd3c5bc/0.0.0/37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99)
# 10/27/2025 15:45:14 - INFO - datasets.builder - Downloading and preparing dataset text/default to C:/Users/Dev/.cache/huggingface/datasets/text/default-5d3022183dd3c5bc/0.0.0/37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99...
# 10/27/2025 15:45:14 - INFO - datasets.download.download_manager - Downloading took 0.0 min
# 10/27/2025 15:45:14 - INFO - datasets.download.download_manager - Checksum Computation took 0.0 min
# 10/27/2025 15:45:14 - INFO - datasets.builder - Generating train split
# 10/27/2025 15:45:14 - INFO - datasets.builder - Generating validation split
# 10/27/2025 15:45:14 - INFO - datasets.utils.info_utils - Unable to verify splits sizes.
# 10/27/2025 15:45:14 - INFO - datasets.builder - Dataset text downloaded and prepared to C:/Users/Dev/.cache/huggingface/datasets/text/default-5d3022183dd3c5bc/0.0.0/37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99. Subsequent calls will reuse this data.
# 10/27/2025 15:45:20 - INFO - datasets.arrow_dataset - Caching processed dataset at C:\Users\Dev\.cache\huggingface\datasets\text\default-5d3022183dd3c5bc\0.0.0\37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99\cache-720a9207cd9660c8.arrow
# 10/27/2025 15:45:20 - INFO - datasets.arrow_dataset - Caching processed dataset at C:\Users\Dev\.cache\huggingface\datasets\text\default-5d3022183dd3c5bc\0.0.0\37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99\cache-d63265af6df1029f.arrow
# 10/27/2025 15:45:20 - WARNING - __main__ - The tokenizer picked seems to have a very large `model_max_length` (1000000000000000019884624838656). Using block_size=1024 instead. You can change that default value by passing --block_size xxx.
# 10/27/2025 15:45:20 - INFO - datasets.arrow_dataset - Caching processed dataset at C:\Users\Dev\.cache\huggingface\datasets\text\default-5d3022183dd3c5bc\0.0.0\37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99\cache-7481792952616325.arrow
# 10/27/2025 15:45:20 - INFO - datasets.arrow_dataset - Caching processed dataset at C:\Users\Dev\.cache\huggingface\datasets\text\default-5d3022183dd3c5bc\0.0.0\37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99\cache-754747f16501a074.arrow
# {'eval_runtime': 0.0066, 'eval_samples_per_second': 0.0, 'eval_steps_per_second': 0.0, 'epoch': 1.0}
# {'eval_runtime': 0.0041, 'eval_samples_per_second': 0.0, 'eval_steps_per_second': 0.0, 'epoch': 2.0}
# {'eval_runtime': 0.0041, 'eval_samples_per_second': 0.0, 'eval_steps_per_second': 0.0, 'epoch': 3.0}
# {'train_runtime': 125.2554, 'train_samples_per_second': 0.048, 'train_steps_per_second': 0.024, 'train_loss': 5.204752604166667, 'epoch': 3.0}
# ***** train metrics *****
#   epoch                    =        3.0
#   total_flos               =    24320GF
#   train_loss               =     5.2048
#   train_runtime            = 0:02:05.25
#   train_samples            =          2
#   train_samples_per_second =      0.048
#   train_steps_per_second   =      0.024
# 10/27/2025 15:47:36 - INFO - __main__ - *** Evaluate ***
# ¡Entrenamiento completado! Modelo guardado en C:/temp/protgpt2_finetuned
# Using custom data configuration default-5d3022183dd3c5bc
# Generating dataset text (C:/Users/Dev/.cache/huggingface/datasets/text/default-5d3022183dd3c5bc/0.0.0/37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99)
# Downloading and preparing dataset text/default to C:/Users/Dev/.cache/huggingface/datasets/text/default-5d3022183dd3c5bc/0.0.0/37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99...
# Downloading took 0.0 min
# Checksum Computation took 0.0 min
# Generating train split
#
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 404 examples [00:00, 11482.99 examples/s]
# Generating validation split
#
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating validation split: 46 examples [00:00, 6360.24 examples/s]
# Unable to verify splits sizes.
# Dataset text downloaded and prepared to C:/Users/Dev/.cache/huggingface/datasets/text/default-5d3022183dd3c5bc/0.0.0/37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99. Subsequent calls will reuse this data.
# [INFO|configuration_utils.py:717] 2025-10-27 15:45:16,830 >> loading configuration file config.json from cache at C:\Users\Dev\.cache\huggingface\hub\models--nferruz--ProtGPT2\snapshots\f71aa6cf063ad784ebd53881d11332fd098eaa58\config.json
# [INFO|configuration_utils.py:788] 2025-10-27 15:45:16,830 >> Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 0,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 0,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1280,
#   "n_head": 20,
#   "n_inner": null,
#   "n_layer": 36,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "5.0.0.dev0",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# [INFO|tokenization_auto.py:913] 2025-10-27 15:45:16,919 >> Could not locate the tokenizer configuration file, will try to use the model config instead.
# [INFO|configuration_utils.py:717] 2025-10-27 15:45:17,035 >> loading configuration file config.json from cache at C:\Users\Dev\.cache\huggingface\hub\models--nferruz--ProtGPT2\snapshots\f71aa6cf063ad784ebd53881d11332fd098eaa58\config.json
# [INFO|configuration_utils.py:788] 2025-10-27 15:45:17,035 >> Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 0,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 0,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1280,
#   "n_head": 20,
#   "n_inner": null,
#   "n_layer": 36,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "5.0.0.dev0",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# [INFO|tokenization_utils_base.py:2102] 2025-10-27 15:45:17,352 >> loading file vocab.json from cache at C:\Users\Dev\.cache\huggingface\hub\models--nferruz--ProtGPT2\snapshots\f71aa6cf063ad784ebd53881d11332fd098eaa58\vocab.json
# [INFO|tokenization_utils_base.py:2102] 2025-10-27 15:45:17,352 >> loading file merges.txt from cache at C:\Users\Dev\.cache\huggingface\hub\models--nferruz--ProtGPT2\snapshots\f71aa6cf063ad784ebd53881d11332fd098eaa58\merges.txt
# [INFO|tokenization_utils_base.py:2102] 2025-10-27 15:45:17,352 >> loading file tokenizer.json from cache at C:\Users\Dev\.cache\huggingface\hub\models--nferruz--ProtGPT2\snapshots\f71aa6cf063ad784ebd53881d11332fd098eaa58\tokenizer.json
# [INFO|tokenization_utils_base.py:2102] 2025-10-27 15:45:17,352 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2102] 2025-10-27 15:45:17,352 >> loading file special_tokens_map.json from cache at C:\Users\Dev\.cache\huggingface\hub\models--nferruz--ProtGPT2\snapshots\f71aa6cf063ad784ebd53881d11332fd098eaa58\special_tokens_map.json
# [INFO|tokenization_utils_base.py:2102] 2025-10-27 15:45:17,352 >> loading file tokenizer_config.json from cache at None
# [INFO|tokenization_utils_base.py:2102] 2025-10-27 15:45:17,352 >> loading file chat_template.jinja from cache at None
# [INFO|configuration_utils.py:717] 2025-10-27 15:45:17,352 >> loading configuration file config.json from cache at C:\Users\Dev\.cache\huggingface\hub\models--nferruz--ProtGPT2\snapshots\f71aa6cf063ad784ebd53881d11332fd098eaa58\config.json
# [INFO|configuration_utils.py:788] 2025-10-27 15:45:17,354 >> Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 0,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 0,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1280,
#   "n_head": 20,
#   "n_inner": null,
#   "n_layer": 36,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "5.0.0.dev0",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# [INFO|modeling_utils.py:1050] 2025-10-27 15:45:17,607 >> loading weights file pytorch_model.bin from cache at C:\Users\Dev\.cache\huggingface\hub\models--nferruz--ProtGPT2\snapshots\f71aa6cf063ad784ebd53881d11332fd098eaa58\pytorch_model.bin
# [INFO|configuration_utils.py:964] 2025-10-27 15:45:17,609 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "eos_token_id": 0
# }
#
# [INFO|safetensors_conversion.py:61] 2025-10-27 15:45:17,690 >> Attempting to create safetensors variant
# [INFO|safetensors_conversion.py:74] 2025-10-27 15:45:18,195 >> Safetensors PR exists
# [INFO|utils.py:410] 2025-10-27 15:45:20,070 >> Generation config file not found, using a generation config created from the model config.
# [INFO|dynamic_module_utils.py:407] 2025-10-27 15:45:20,163 >> Could not locate the custom_generate/generate.py inside nferruz/ProtGPT2.
#
# Running tokenizer on dataset:   0%|          | 0/404 [00:00<?, ? examples/s]Caching processed dataset at C:\Users\Dev\.cache\huggingface\datasets\text\default-5d3022183dd3c5bc\0.0.0\37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99\cache-720a9207cd9660c8.arrow
#
# Running tokenizer on dataset: 100%|██████████| 404/404 [00:00<00:00, 6638.06 examples/s]
#
# Running tokenizer on dataset:   0%|          | 0/46 [00:00<?, ? examples/s]Caching processed dataset at C:\Users\Dev\.cache\huggingface\datasets\text\default-5d3022183dd3c5bc\0.0.0\37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99\cache-d63265af6df1029f.arrow
#
# Running tokenizer on dataset: 100%|██████████| 46/46 [00:00<00:00, 2621.05 examples/s]
#
# Grouping texts in chunks of 1024:   0%|          | 0/404 [00:00<?, ? examples/s]Caching processed dataset at C:\Users\Dev\.cache\huggingface\datasets\text\default-5d3022183dd3c5bc\0.0.0\37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99\cache-7481792952616325.arrow
#
# Grouping texts in chunks of 1024: 100%|██████████| 404/404 [00:00<00:00, 14848.66 examples/s]
#
# Grouping texts in chunks of 1024:   0%|          | 0/46 [00:00<?, ? examples/s]Caching processed dataset at C:\Users\Dev\.cache\huggingface\datasets\text\default-5d3022183dd3c5bc\0.0.0\37eaf37ac90527a7fd768c94b312ee84f8815c9b7ac00acf81c1c364e8392f99\cache-754747f16501a074.arrow
#
# Grouping texts in chunks of 1024: 100%|██████████| 46/46 [00:00<00:00, 2476.83 examples/s]
#
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 4.20kB [00:00, ?B/s]
# [INFO|trainer.py:2335] 2025-10-27 15:45:26,582 >> ***** Running training *****
# [INFO|trainer.py:2336] 2025-10-27 15:45:26,582 >>   Num examples = 2
# [INFO|trainer.py:2337] 2025-10-27 15:45:26,582 >>   Num Epochs = 3
# [INFO|trainer.py:2338] 2025-10-27 15:45:26,582 >>   Instantaneous batch size per device = 2
# [INFO|trainer.py:2341] 2025-10-27 15:45:26,582 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:2342] 2025-10-27 15:45:26,582 >>   Gradient Accumulation steps = 4
# [INFO|trainer.py:2343] 2025-10-27 15:45:26,582 >>   Total optimization steps = 3
# [INFO|trainer.py:2344] 2025-10-27 15:45:26,584 >>   Number of trainable parameters = 774,030,080
#
#   0%|          | 0/3 [00:00<?, ?it/s][WARNING|logging.py:327] 2025-10-27 15:45:27,778 >> `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#
#  33%|███▎      | 1/3 [00:07<00:15,  7.99s/it][INFO|trainer.py:4354] 2025-10-27 15:45:34,592 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:4356] 2025-10-27 15:45:34,593 >>   Num examples = 0
# [INFO|trainer.py:4359] 2025-10-27 15:45:34,593 >>   Batch size = 2
#
#
#
#  33%|███▎      | 1/3 [00:08<00:15,  7.99s/it][INFO|trainer.py:4026] 2025-10-27 15:45:34,597 >> Saving model checkpoint to C:/temp/protgpt2_finetuned\checkpoint-1
# [INFO|configuration_utils.py:479] 2025-10-27 15:45:34,602 >> Configuration saved in C:/temp/protgpt2_finetuned\checkpoint-1\config.json
# [INFO|configuration_utils.py:752] 2025-10-27 15:45:34,603 >> Configuration saved in C:/temp/protgpt2_finetuned\checkpoint-1\generation_config.json
# [INFO|modeling_utils.py:3841] 2025-10-27 15:45:43,357 >> Model weights saved in C:/temp/protgpt2_finetuned\checkpoint-1\model.safetensors
# [INFO|tokenization_utils_base.py:2585] 2025-10-27 15:45:43,373 >> tokenizer config file saved in C:/temp/protgpt2_finetuned\checkpoint-1\tokenizer_config.json
# [INFO|tokenization_utils_base.py:2594] 2025-10-27 15:45:43,379 >> Special tokens file saved in C:/temp/protgpt2_finetuned\checkpoint-1\special_tokens_map.json
#
#  67%|██████▋   | 2/3 [00:55<00:30, 31.00s/it][INFO|trainer.py:4354] 2025-10-27 15:46:21,693 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:4356] 2025-10-27 15:46:21,693 >>   Num examples = 0
# [INFO|trainer.py:4359] 2025-10-27 15:46:21,693 >>   Batch size = 2
#
#
#
#  67%|██████▋   | 2/3 [00:55<00:30, 31.00s/it][INFO|trainer.py:4026] 2025-10-27 15:46:21,700 >> Saving model checkpoint to C:/temp/protgpt2_finetuned\checkpoint-2
# [INFO|configuration_utils.py:479] 2025-10-27 15:46:21,706 >> Configuration saved in C:/temp/protgpt2_finetuned\checkpoint-2\config.json
# [INFO|configuration_utils.py:752] 2025-10-27 15:46:21,713 >> Configuration saved in C:/temp/protgpt2_finetuned\checkpoint-2\generation_config.json
# [INFO|modeling_utils.py:3841] 2025-10-27 15:46:34,621 >> Model weights saved in C:/temp/protgpt2_finetuned\checkpoint-2\model.safetensors
# [INFO|tokenization_utils_base.py:2585] 2025-10-27 15:46:34,628 >> tokenizer config file saved in C:/temp/protgpt2_finetuned\checkpoint-2\tokenizer_config.json
# [INFO|tokenization_utils_base.py:2594] 2025-10-27 15:46:34,633 >> Special tokens file saved in C:/temp/protgpt2_finetuned\checkpoint-2\special_tokens_map.json
#
# 100%|██████████| 3/3 [01:49<00:00, 41.47s/it][INFO|trainer.py:4354] 2025-10-27 15:47:15,624 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:4356] 2025-10-27 15:47:15,624 >>   Num examples = 0
# [INFO|trainer.py:4359] 2025-10-27 15:47:15,624 >>   Batch size = 2
#
#
#
# 100%|██████████| 3/3 [01:49<00:00, 41.47s/it][INFO|trainer.py:4026] 2025-10-27 15:47:15,630 >> Saving model checkpoint to C:/temp/protgpt2_finetuned\checkpoint-3
# [INFO|configuration_utils.py:479] 2025-10-27 15:47:15,637 >> Configuration saved in C:/temp/protgpt2_finetuned\checkpoint-3\config.json
# [INFO|configuration_utils.py:752] 2025-10-27 15:47:15,643 >> Configuration saved in C:/temp/protgpt2_finetuned\checkpoint-3\generation_config.json
# [INFO|modeling_utils.py:3841] 2025-10-27 15:47:20,749 >> Model weights saved in C:/temp/protgpt2_finetuned\checkpoint-3\model.safetensors
# [INFO|tokenization_utils_base.py:2585] 2025-10-27 15:47:20,754 >> tokenizer config file saved in C:/temp/protgpt2_finetuned\checkpoint-3\tokenizer_config.json
# [INFO|tokenization_utils_base.py:2594] 2025-10-27 15:47:20,756 >> Special tokens file saved in C:/temp/protgpt2_finetuned\checkpoint-3\special_tokens_map.json
# [INFO|trainer.py:2608] 2025-10-27 15:47:31,838 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
#
#
#
# 100%|██████████| 3/3 [02:05<00:00, 41.47s/it]
# 100%|██████████| 3/3 [02:05<00:00, 41.76s/it]
# [INFO|trainer.py:4026] 2025-10-27 15:47:31,870 >> Saving model checkpoint to C:/temp/protgpt2_finetuned
# [INFO|configuration_utils.py:479] 2025-10-27 15:47:31,874 >> Configuration saved in C:/temp/protgpt2_finetuned\config.json
# [INFO|configuration_utils.py:752] 2025-10-27 15:47:31,877 >> Configuration saved in C:/temp/protgpt2_finetuned\generation_config.json
# [INFO|modeling_utils.py:3841] 2025-10-27 15:47:36,029 >> Model weights saved in C:/temp/protgpt2_finetuned\model.safetensors
# [INFO|tokenization_utils_base.py:2585] 2025-10-27 15:47:36,041 >> tokenizer config file saved in C:/temp/protgpt2_finetuned\tokenizer_config.json
# [INFO|tokenization_utils_base.py:2594] 2025-10-27 15:47:36,044 >> Special tokens file saved in C:/temp/protgpt2_finetuned\special_tokens_map.json
# [INFO|trainer.py:4354] 2025-10-27 15:47:36,184 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:4356] 2025-10-27 15:47:36,184 >>   Num examples = 0
# [INFO|trainer.py:4359] 2025-10-27 15:47:36,184 >>   Batch size = 2
# Traceback (most recent call last):
#   File "c:\Users\Dev\AppData\Local\Programs\Microsoft VS Code\run_clm.py", line 711, in <module>
#     main()
#   File "c:\Users\Dev\AppData\Local\Programs\Microsoft VS Code\run_clm.py", line 682, in main
#     perplexity = math.exp(metrics["eval_loss"])
#                           ~~~~~~~^^^^^^^^^^^^^
# KeyError: 'eval_loss'

# %%
print(os.listdir("."))
# Out:
# ['appx', 'bin', 'chrome_100_percent.pak', 'chrome_200_percent.pak', 'Code.exe', 'Code.VisualElementsManifest.xml', 'd3dcompiler_47.dll', 'ffmpeg.dll', 'icudtl.dat', 'libEGL.dll', 'libGLESv2.dll', 'LICENSES.chromium.html', 'locales', 'policies', 'resources', 'resources.pak', 'run_clm.py', 'snapshot_blob.bin', 'tools', 'training.txt', 'unins000.dat', 'unins000.exe', 'unins000.msg', 'v8_context_snapshot.bin', 'validation.txt', 'vk_swiftshader.dll', 'vk_swiftshader_icd.json', 'vulkan-1.dll']
